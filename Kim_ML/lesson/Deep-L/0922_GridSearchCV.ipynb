# %% [markdown]
# ## sklearn으로 하이퍼파라미터 튜닝🔥
# ## GridSearchCV , RandomSearchCV

# %% [markdown]
# https://www.dacon.io/codeshare/4568

# %% [markdown]
# - 하이퍼파라미터
#     - 사용자의 입력값, 즉 우리가 설정 가능한 입력값
#     - 사용할 데이터에 따라 가장 적합한 모델, 그리고 그 모델의 하이퍼 파라미터값이 다름
#     - 좋은 파라미터 입력값을 찾아주는 작업 => 튜닝
#         - GridSearchCV
#             - 목표로 하는 하이퍼 파라미터별로 리스트를 만들어 딕셔너리 형태로 파라미터 셋을 입력

# %%
import sklearn
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import warnings
warnings.filterwarnings('ignore')

# %%
iris=load_iris()

# %%
label=iris.target
data=iris.data

# %%
# train & test data 분리
x_train, x_test, y_train, y_test=train_test_split(iris.data,
                                                 iris.target,
                                                 test_size=0.2,
                                                 random_state=1)

# %%
# DecisionTreeClassifier()
dt_clf=DecisionTreeClassifier(random_state=1)

# %%
# DecisionTreeClassifier().fit
dt_clf.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
# DecisionTreeClassifier().fit().predict()
predict=dt_clf.predict(x_test)

# %%
# accaccuracy_score(답안지, 예측값)
accuracy=accuracy_score(y_test, predict)
print('예측 정확도 : {0:.4f}'.format(accuracy))
# Out:
# 예측 정확도 : 0.9667

# %%
# 의사결정나무의 하이퍼 파라미터 출력
print(f'dt_clf의 하이퍼 파라미터 => {dt_clf.get_params()}')
# Out:
# dt_clf의 하이퍼 파라미터 => {'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 1, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'random_state': 1, 'splitter': 'best'}

# %% [markdown]
# ###### 의사결정나무에서 최적의 값을 찾아낼 파라매터들
#
# *criterion* : 분할 성능 측정 기능
#
# *min_samples_split* : 노드를 분할하기 위한 최소한의 샘플 데이터수로, 과적합을 제어하는데 주로 사용함. 작게 설정할 수록 분할 노드가 많아져 과적합 가능성이 높아짐.
#
# *max_depth* : 트리의 최대 깊이, 깊이가 깊어지면 과적합될 수 있음.
#
# *max_features* : 최적의 분할을 위해 고려할 최대 feature 개수 (default = *None* : 데이터 세트의 모든 피처를 사용)
#
# *min_samples_leaf* : 리프노드가 되기 위해 필요한 최소한의 샘플 데이터수 (과적합 제어 용도), 작게 설정 필요
#
# *max_leaf_nodes* : 리프노드의 최대 개수

# %%
# 파라미터별로 리스트를 만들고,
# 파라미터 세트를 딕셔너리로 만들기
param_grid = {
    'criterion':['gini','entropy'], 
    'max_depth':[None,2,3,4,5,6], 
    'max_leaf_nodes':[None,2,3,4,5,6,7], 
    'min_samples_split':[2,3,4,5,6], 
    'min_samples_leaf':[1,2,3], 
    'max_features':[None,'sqrt','log2',3,4,5]
    }

# %% [markdown]
# ### GridSearchCV 의 인자들
#
# estimator : 보통 알고리즘을 객체로 만들어 넣어준다.
#
# param_grid : 튜닝을 위한 대상 파라미터, 사용될 파라미터를 딕셔너리 형태로 넣어준다.
#
# scoring : 예측 성능을 측정할 평가 방법을 넣는다. 분류 알고리즘일 때는, 'accuracy', 'f1', 회귀 알고리즘일 때는 'neg_mean_squared_error', 'r2' 등을 넣을 수 있다.
#
# cv : 교차 검증에서 몇개로 분할되는지 지정한다.(정수로 넣어주면 K겹 교차검증이 되고, KFold(k) 이런식으로 넣어주어도 무방 // default 값은 cv=3)
#
# refit : True로 하면 최적의 하이퍼 파라미터를 찾아서 estimator를 재학습시킨다. (default 값이 True임)

# %%
grid_search=GridSearchCV(dt_clf, param_grid=param_grid, cv=5,
                        scoring='accuracy', refit=True)

# %%
grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 2, 3, 4, 5, 6],
#                          'max_features': [None, 'sqrt', 'log2', 3, 4, 5],
#                          'max_leaf_nodes': [None, 2, 3, 4, 5, 6, 7],
#                          'min_samples_leaf': [1, 2, 3],
#                          'min_samples_split': [2, 3, 4, 5, 6]},
#              scoring='accuracy')

# %% [markdown]
# #### 가장 최적 하이퍼 파라미터들의 값, 최고 평균 정확도 수치를 확인
#
# GridSearchCV객체.best_params_ : 최적 하이퍼 파라미터 조합
#
# GridSearchCV객체.best_score_ : 최고 평균 정확도 수치

# %%
print('최적의 하이퍼 파라미터 조합 : ', grid_search.best_params_)
print('최고 평균 정확도 수치 : ', grid_search.best_score_)
# Out:
# 최적의 하이퍼 파라미터 조합 :  {'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2}
# 최고 평균 정확도 수치 :  0.9666666666666668

# %% [markdown]
# GridSearchCV는 입력한 하이퍼 파라미터값들을 순차적으로 변경하며 학습과 평가를 수행함.
#
# 그리고 cv_results_ 라는 속성에 딕셔너리의 기록하게 되는데, 좀 더 편하게 보기위헤 데이터 프레임으로 변경

# %%
cv_resultsDF=pd.DataFrame(grid_search.cv_results_)
cv_resultsDF.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.001196      0.000401         0.000198        0.000397
# 1       0.001190      0.000745         0.000598        0.000488
# 2       0.000804      0.000402         0.000200        0.000399
# 3       0.000903      0.000658         0.000000        0.000000
# 4       0.000592      0.000484         0.000200        0.000399
#
#   param_criterion param_max_depth param_max_features param_max_leaf_nodes  \
# 0            gini            None               None                 None
# 1            gini            None               None                 None
# 2            gini            None               None                 None
# 3            gini            None               None                 None
# 4            gini            None               None                 None
#
#   param_min_samples_leaf param_min_samples_split  \
# 0                      1                       2
# 1                      1                       3
# 2                      1                       4
# 3                      1                       5
# 4                      1                       6
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': None, 'max_...           0.958333
# 1  {'criterion': 'gini', 'max_depth': None, 'max_...           0.958333
# 2  {'criterion': 'gini', 'max_depth': None, 'max_...           0.958333
# 3  {'criterion': 'gini', 'max_depth': None, 'max_...           0.958333
# 4  {'criterion': 'gini', 'max_depth': None, 'max_...           0.958333
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.958333           1.000000           0.958333           0.958333
# 1           0.958333           1.000000           0.958333           0.875000
# 2           0.958333           1.000000           0.958333           0.875000
# 3           0.958333           1.000000           0.958333           0.875000
# 4           0.958333           0.916667           0.958333           0.875000
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.016667                1
# 1         0.950000        0.040825               86
# 2         0.950000        0.040825               86
# 3         0.950000        0.040825               86
# 4         0.933333        0.033333              334

# %% [markdown]
# ##### 하이퍼 파라미터의 값이 변화함에 따라 테스트 스코어가 달라짐

# %% [markdown]
# GridSearchCV객체.best_estimator_는 GridSearchCV의 refit으로 이미 학습이 된 estimator를 반환함.
#
# 따라서 best_estimator_는 이미 최적 하이퍼 파라미터를 적용하여 학습이 된 상태

# %%
estimator=grid_search.best_estimator_

# %%
pred=estimator.predict(x_test)

# %%
print('score : ', accuracy_score(y_test, pred))
# Out:
# score :  0.9666666666666667

# %%
# 단점 : 시간 소요가 큼

# %% [markdown]
# ---
# ## RandomizedSearchCV
# - GridSearch 와 동일한 방식으로 사용하지만 모든 조합을 다 시도하지는 않고, 각 반복마다 임의의 값만 대입해 지정한 횟수만큼 평가
# - 몇 번 학습과 평가를 반복할 것인지 시도의 수를 우리가 설정할 수 있기 때문에 비교적 시간이 적게 걸림

# %% [markdown]
# - RandomizedSearchCV 가 사용하는 인자들은 GridSearchCV와 거의 동일하지만, n_iter 라는 인자가 추가, param_grid 대신 param_distributions 를 사용
#
# - param_distributions : 튜닝을 위한 대상 파라미터, 사용될 파라미터를 딕셔너리 형태로 넣어준다.
#
# - n_iter : 파라미터 검색 횟수
#
# - n_iter 의 default는 10, RandomizedSearchCV 는 우리가 n_iter에 지정한 횟수만큼만 조합을 반복하여 평가

# %%
from sklearn.model_selection import RandomizedSearchCV

dt_clf = DecisionTreeClassifier(random_state=1)

param_dist = {
    'criterion':['gini','entropy'], 
    'max_depth':[None,2,3,4,5,6], 
    'max_leaf_nodes':[None,2,3,4,5,6,7], 
    'min_samples_split':[2,3,4,5,6], 
    'min_samples_leaf':[1,2,3], 
    'max_features':[None,'sqrt','log2',3,4,5]
    }

# %%
rand_search = RandomizedSearchCV(dt_clf, param_distributions = param_dist, n_iter = 50, cv = 5, scoring = 'accuracy', refit=True)
rand_search.fit(x_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1),
#                    n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [None, 2, 3, 4, 5, 6],
#                                         'max_features': [None, 'sqrt', 'log2',
#                                                          3, 4, 5],
#                                         'max_leaf_nodes': [None, 2, 3, 4, 5, 6,
#                                                            7],
#                                         'min_samples_leaf': [1, 2, 3],
#                                         'min_samples_split': [2, 3, 4, 5, 6]},
#                    scoring='accuracy')

# %%
print('best parameters : ', rand_search.best_params_)
print('best score : ', round(rand_search.best_score_, 4))
# Out:
# best parameters :  {'min_samples_split': 4, 'min_samples_leaf': 1, 'max_leaf_nodes': 6, 'max_features': None, 'max_depth': 6, 'criterion': 'gini'}
# best score :  0.95

# %%
df = pd.DataFrame(rand_search.cv_results_)
df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000809      0.000405         0.000000        0.000000
# 1        0.000797      0.000745         0.000399        0.000489
# 2        0.000999      0.000004         0.000398        0.000488
# 3        0.001194      0.000399         0.000000        0.000000
# 4        0.001002      0.000006         0.000599        0.000489
# 5        0.000801      0.000401         0.000399        0.000488
# 6        0.000993      0.000012         0.000000        0.000000
# 7        0.000593      0.000795         0.000398        0.000488
# 8        0.000592      0.000787         0.000394        0.000483
# 9        0.000798      0.000399         0.000200        0.000400
# 10       0.000399      0.000489         0.000000        0.000000
# 11       0.000000      0.000000         0.000198        0.000396
# 12       0.000199      0.000399         0.000605        0.000495
# 13       0.000598      0.000488         0.000399        0.000488
# 14       0.000395      0.000484         0.000199        0.000397
# 15       0.000000      0.000000         0.000601        0.000491
# 16       0.000602      0.000492         0.000396        0.000485
# 17       0.000392      0.000481         0.000398        0.000488
# 18       0.000795      0.000397         0.000602        0.000492
# 19       0.000998      0.000020         0.000000        0.000000
# 20       0.000993      0.000008         0.000000        0.000000
# 21       0.000611      0.000499         0.000000        0.000000
# 22       0.000991      0.000014         0.000000        0.000000
# 23       0.000597      0.000488         0.000000        0.000000
# 24       0.000405      0.000496         0.000193        0.000385
# 25       0.000000      0.000000         0.000599        0.000489
# 26       0.000000      0.000000         0.000000        0.000000
# 27       0.000602      0.000492         0.000397        0.000486
# 28       0.000400      0.000490         0.000401        0.000491
# 29       0.000997      0.000004         0.000000        0.000000
# 30       0.001196      0.000399         0.000000        0.000000
# 31       0.000799      0.000399         0.000199        0.000398
# 32       0.000598      0.000489         0.000400        0.000490
# 33       0.000592      0.000484         0.000000        0.000000
# 34       0.000199      0.000398         0.000798        0.000399
# 35       0.000199      0.000399         0.000598        0.000489
# 36       0.000602      0.000805         0.000000        0.000000
# 37       0.000600      0.000490         0.000000        0.000000
# 38       0.000400      0.000490         0.000000        0.000000
# 39       0.000794      0.000398         0.000203        0.000407
# 40       0.000998      0.000021         0.000199        0.000399
# 41       0.000797      0.000398         0.000000        0.000000
# 42       0.000397      0.000486         0.000594        0.000485
# 43       0.000398      0.000488         0.000000        0.000000
# 44       0.000399      0.000489         0.000000        0.000000
# 45       0.000796      0.000398         0.000397        0.000487
# 46       0.000798      0.000399         0.000000        0.000000
# 47       0.000598      0.000489         0.000605        0.000494
# 48       0.000598      0.000488         0.000000        0.000000
# 49       0.000599      0.000489         0.000000        0.000000
#
#    param_min_samples_split param_min_samples_leaf param_max_leaf_nodes  \
# 0                        3                      2                    3
# 1                        5                      2                    3
# 2                        6                      1                    7
# 3                        3                      3                    4
# 4                        3                      2                    5
# 5                        2                      1                    2
# 6                        4                      2                    2
# 7                        5                      3                    2
# 8                        2                      1                    5
# 9                        4                      1                    6
# 10                       5                      2                    3
# 11                       4                      1                    5
# 12                       4                      1                    7
# 13                       5                      2                    4
# 14                       3                      1                 None
# 15                       4                      2                    6
# 16                       6                      1                 None
# 17                       6                      2                    4
# 18                       3                      2                 None
# 19                       5                      3                    7
# 20                       4                      3                    3
# 21                       4                      1                    4
# 22                       2                      3                 None
# 23                       2                      2                    6
# 24                       6                      1                 None
# 25                       4                      1                    6
# 26                       6                      3                    6
# 27                       4                      1                    4
# 28                       4                      2                 None
# 29                       2                      1                    6
# 30                       3                      3                    7
# 31                       4                      1                    3
# 32                       6                      1                    3
# 33                       6                      1                    6
# 34                       5                      1                    5
# 35                       4                      1                    5
# 36                       3                      2                    6
# 37                       2                      2                 None
# 38                       4                      1                 None
# 39                       4                      1                    5
# 40                       5                      3                    4
# 41                       5                      2                    2
# 42                       6                      1                    6
# 43                       3                      2                    5
# 44                       4                      2                    4
# 45                       5                      2                    7
# 46                       4                      2                    6
# 47                       2                      1                    5
# 48                       6                      2                    4
# 49                       2                      1                    6
#
#    param_max_features param_max_depth param_criterion  \
# 0                   5            None         entropy
# 1                   4               2         entropy
# 2                sqrt               3            gini
# 3                   3            None         entropy
# 4                   3               6            gini
# 5                None               5            gini
# 6                   3               5            gini
# 7                None            None         entropy
# 8                None            None         entropy
# 9                None               6            gini
# 10                  3               2            gini
# 11               None               3         entropy
# 12                  3               2         entropy
# 13               None            None            gini
# 14                  3            None         entropy
# 15               sqrt               5         entropy
# 16                  3               5            gini
# 17               sqrt            None         entropy
# 18                  4               6            gini
# 19                  4               5         entropy
# 20               log2               3         entropy
# 21                  5               5            gini
# 22               sqrt            None         entropy
# 23               None               6         entropy
# 24               log2               5         entropy
# 25               sqrt               2            gini
# 26                  3               5         entropy
# 27                  3               3         entropy
# 28               None            None         entropy
# 29               log2            None         entropy
# 30               sqrt               6         entropy
# 31               sqrt               5            gini
# 32                  4               3            gini
# 33                  5               4            gini
# 34                  3            None         entropy
# 35               None            None            gini
# 36               sqrt               4            gini
# 37               None               6         entropy
# 38                  5               3            gini
# 39                  4               5         entropy
# 40                  3               2            gini
# 41                  3            None            gini
# 42               log2               4            gini
# 43                  5               3            gini
# 44                  5               2         entropy
# 45               sqrt               5            gini
# 46                  4               4            gini
# 47               sqrt               2         entropy
# 48               log2               5            gini
# 49               sqrt               4            gini
#
#                                                params  split0_test_score  \
# 0   {'min_samples_split': 3, 'min_samples_leaf': 2...                NaN
# 1   {'min_samples_split': 5, 'min_samples_leaf': 2...           0.958333
# 2   {'min_samples_split': 6, 'min_samples_leaf': 1...           0.916667
# 3   {'min_samples_split': 3, 'min_samples_leaf': 3...           0.958333
# 4   {'min_samples_split': 3, 'min_samples_leaf': 2...           0.958333
# 5   {'min_samples_split': 2, 'min_samples_leaf': 1...           0.666667
# 6   {'min_samples_split': 4, 'min_samples_leaf': 2...           0.666667
# 7   {'min_samples_split': 5, 'min_samples_leaf': 3...           0.666667
# 8   {'min_samples_split': 2, 'min_samples_leaf': 1...           0.958333
# 9   {'min_samples_split': 4, 'min_samples_leaf': 1...           0.958333
# 10  {'min_samples_split': 5, 'min_samples_leaf': 2...           0.958333
# 11  {'min_samples_split': 4, 'min_samples_leaf': 1...           0.958333
# 12  {'min_samples_split': 4, 'min_samples_leaf': 1...           0.958333
# 13  {'min_samples_split': 5, 'min_samples_leaf': 2...           0.958333
# 14  {'min_samples_split': 3, 'min_samples_leaf': 1...           0.958333
# 15  {'min_samples_split': 4, 'min_samples_leaf': 2...           0.958333
# 16  {'min_samples_split': 6, 'min_samples_leaf': 1...           0.958333
# 17  {'min_samples_split': 6, 'min_samples_leaf': 2...           1.000000
# 18  {'min_samples_split': 3, 'min_samples_leaf': 2...           0.958333
# 19  {'min_samples_split': 5, 'min_samples_leaf': 3...           0.958333
# 20  {'min_samples_split': 4, 'min_samples_leaf': 3...           1.000000
# 21  {'min_samples_split': 4, 'min_samples_leaf': 1...                NaN
# 22  {'min_samples_split': 2, 'min_samples_leaf': 3...           0.958333
# 23  {'min_samples_split': 2, 'min_samples_leaf': 2...           0.958333
# 24  {'min_samples_split': 6, 'min_samples_leaf': 1...           0.958333
# 25  {'min_samples_split': 4, 'min_samples_leaf': 1...           1.000000
# 26  {'min_samples_split': 6, 'min_samples_leaf': 3...           0.958333
# 27  {'min_samples_split': 4, 'min_samples_leaf': 1...           0.958333
# 28  {'min_samples_split': 4, 'min_samples_leaf': 2...           0.958333
# 29  {'min_samples_split': 2, 'min_samples_leaf': 1...           1.000000
# 30  {'min_samples_split': 3, 'min_samples_leaf': 3...           0.958333
# 31  {'min_samples_split': 4, 'min_samples_leaf': 1...           1.000000
# 32  {'min_samples_split': 6, 'min_samples_leaf': 1...           0.958333
# 33  {'min_samples_split': 6, 'min_samples_leaf': 1...                NaN
# 34  {'min_samples_split': 5, 'min_samples_leaf': 1...           0.958333
# 35  {'min_samples_split': 4, 'min_samples_leaf': 1...           0.958333
# 36  {'min_samples_split': 3, 'min_samples_leaf': 2...           0.916667
# 37  {'min_samples_split': 2, 'min_samples_leaf': 2...           0.958333
# 38  {'min_samples_split': 4, 'min_samples_leaf': 1...                NaN
# 39  {'min_samples_split': 4, 'min_samples_leaf': 1...           0.958333
# 40  {'min_samples_split': 5, 'min_samples_leaf': 3...           0.958333
# 41  {'min_samples_split': 5, 'min_samples_leaf': 2...           0.666667
# 42  {'min_samples_split': 6, 'min_samples_leaf': 1...           0.916667
# 43  {'min_samples_split': 3, 'min_samples_leaf': 2...                NaN
# 44  {'min_samples_split': 4, 'min_samples_leaf': 2...                NaN
# 45  {'min_samples_split': 5, 'min_samples_leaf': 2...           0.916667
# 46  {'min_samples_split': 4, 'min_samples_leaf': 2...           0.958333
# 47  {'min_samples_split': 2, 'min_samples_leaf': 1...           1.000000
# 48  {'min_samples_split': 6, 'min_samples_leaf': 2...           1.000000
# 49  {'min_samples_split': 2, 'min_samples_leaf': 1...           0.916667
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1            0.875000           0.916667           0.958333
# 2            0.875000           0.916667           0.916667
# 3            0.958333           0.916667           0.958333
# 4            0.958333           0.916667           0.958333
# 5            0.666667           0.708333           0.708333
# 6            0.666667           0.708333           0.708333
# 7            0.666667           0.708333           0.708333
# 8            0.958333           0.916667           0.958333
# 9            0.958333           1.000000           0.958333
# 10           0.875000           0.916667           0.958333
# 11           0.958333           0.916667           0.958333
# 12           0.875000           0.916667           0.958333
# 13           0.958333           0.916667           0.958333
# 14           0.958333           0.875000           0.958333
# 15           0.875000           0.916667           0.958333
# 16           0.958333           0.916667           0.958333
# 17           0.875000           0.916667           0.958333
# 18           0.958333           0.916667           0.958333
# 19           0.958333           0.791667           0.958333
# 20           0.875000           0.916667           0.958333
# 21                NaN                NaN                NaN
# 22           0.875000           0.833333           0.958333
# 23           0.958333           0.916667           0.958333
# 24           0.875000           0.875000           0.916667
# 25           0.875000           0.916667           0.958333
# 26           0.958333           0.916667           0.958333
# 27           0.958333           0.916667           0.958333
# 28           0.958333           0.791667           0.958333
# 29           0.875000           0.916667           0.916667
# 30           0.875000           0.833333           0.958333
# 31           0.875000           0.916667           0.958333
# 32           0.875000           0.916667           0.958333
# 33                NaN                NaN                NaN
# 34           0.958333           0.916667           0.958333
# 35           0.958333           0.916667           0.958333
# 36           0.958333           0.916667           0.958333
# 37           0.958333           0.791667           0.958333
# 38                NaN                NaN                NaN
# 39           0.958333           0.916667           0.958333
# 40           0.875000           0.916667           0.958333
# 41           0.666667           0.708333           0.708333
# 42           0.958333           0.916667           0.916667
# 43                NaN                NaN                NaN
# 44                NaN                NaN                NaN
# 45           0.958333           0.833333           0.958333
# 46           0.958333           0.916667           0.958333
# 47           0.875000           0.916667           0.958333
# 48           0.875000           0.916667           0.958333
# 49           0.958333           0.916667           0.916667
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               50
# 1            0.875000         0.916667        0.037268               24
# 2            0.916667         0.908333        0.016667               37
# 3            0.875000         0.933333        0.033333                2
# 4            0.875000         0.933333        0.033333                2
# 5            0.708333         0.691667        0.020412               41
# 6            0.708333         0.691667        0.020412               41
# 7            0.708333         0.691667        0.020412               41
# 8            0.875000         0.933333        0.033333                2
# 9            0.875000         0.950000        0.040825                1
# 10           0.875000         0.916667        0.037268               24
# 11           0.875000         0.933333        0.033333                2
# 12           0.875000         0.916667        0.037268               24
# 13           0.875000         0.933333        0.033333                2
# 14           0.833333         0.916667        0.052705               24
# 15           0.916667         0.925000        0.031180               22
# 16           0.875000         0.933333        0.033333                2
# 17           0.916667         0.933333        0.042492                2
# 18           0.875000         0.933333        0.033333                2
# 19           0.875000         0.908333        0.066667               30
# 20           0.916667         0.933333        0.042492                2
# 21                NaN              NaN             NaN               46
# 22           0.916667         0.908333        0.048591               30
# 23           0.875000         0.933333        0.033333                2
# 24           0.916667         0.908333        0.031180               30
# 25           0.916667         0.933333        0.042492                2
# 26           0.875000         0.933333        0.033333                2
# 27           0.875000         0.933333        0.033333                2
# 28           0.875000         0.908333        0.066667               30
# 29           0.916667         0.925000        0.040825               22
# 30           0.916667         0.908333        0.048591               30
# 31           0.916667         0.933333        0.042492                2
# 32           0.875000         0.916667        0.037268               24
# 33                NaN              NaN             NaN               45
# 34           0.875000         0.933333        0.033333                2
# 35           0.875000         0.933333        0.033333                2
# 36           0.791667         0.908333        0.061237               30
# 37           0.875000         0.908333        0.066667               30
# 38                NaN              NaN             NaN               49
# 39           0.875000         0.933333        0.033333                2
# 40           0.875000         0.916667        0.037268               24
# 41           0.708333         0.691667        0.020412               41
# 42           0.791667         0.900000        0.056519               38
# 43                NaN              NaN             NaN               47
# 44                NaN              NaN             NaN               48
# 45           0.833333         0.900000        0.056519               38
# 46           0.875000         0.933333        0.033333                2
# 47           0.916667         0.933333        0.042492                2
# 48           0.916667         0.933333        0.042492                2
# 49           0.791667         0.900000        0.056519               38
